# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats
import re

# %%
df = pd.read_csv('/Users/celina/Desktop/Python/WELLCOME_APCspend2013_forThinkful.csv', encoding = "latin1")

# %%
df.loc[:,'COST (£) charged to Wellcome (inc VAT when charged)'].apply(lambda x: ''.join(list(filter(str.isdigit, str(x)))))
df.loc[:, 'Journal title'].str.upper().str.strip().str.replace('J ','').str.replace('JOURNAL OF ','').str.replace(
    ' J', '').str.replace('AMERICAN CHEMICAL SOCIETY', 'ACS')
# Out:
# 0                            PSYCHOLOGICAL MEDICINE
# 1                                 BIOMACROMOLECULES
# 2                                          MED CHEM
# 3                                          MED CHEM
# 4                                          ORG CHEM
# 5                               MEDICINAL CHEMISTRY
# 6                                 PROTEOME RESEARCH
# 7                                         MOL PHARM
# 8                              ACS CHEMICAL BIOLOGY
# 9                              ACS CHEMICAL BIOLOGY
# 10                CHEMICAL INFORMATION AND MODELING
# 11                              MEDICINAL CHEMISTRY
# 12                              MEDICINAL CHEMISTRY
# 13                                     BIOCHEMISTRY
# 14                              MEDICINAL CHEMISTRY
# 15                                 GASTROENTEROLOGY
# 16                             BIOLOGICAL CHEMISTRY
# 17                                       IMMUNOLOGY
# ...

# %%
df.sort_values('Journal title')
# Out:
#                       PMID/PMCID  \
# 21                           NaN
# 20                 : PMC3805332
# 8              PMCID: PMC3780468
# 9              PMCID: PMC3621575
# 19    PMID: 24015914 PMC3833349
# 22      PMCID:\n    PMC3656742\n
# 23                PMCID: 3584654
# 34                      23373658
# 924                   PMC3374517
# 1808                    23340916
# 2125    PMCID:\n    PMC3647051\n
# 2123                     3748854
# 2115                  PMC3713766
# 1797                     3633780
# 1811                  In Process
# 1824    PMCID:\n    PMC3687248\n
# 2116                  PMC3819359
# 235                  PMC3765690
# 2117                 PMC3773237
# 2118                 PMC3815011
# 1317                         NaN
# 439                 PMC3378987\n
# 927     PMCID:\n    PMC3727331\n
# 920            PMCID: PMC3565438
# 929            PMCID: PMC3606566
# 928            PMCID: PMC3668577
# 921             \n    PMC3498934
# ...
